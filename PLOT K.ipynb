# %%
from pathlib import Path
import os
import shutil
from datetime import datetime
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from pandas import Series, DataFrame
import csv

# %%
#R_v = 0.5. Apresentando erro atípico. 
B = [1.7,1.5,1.4,1.3,1.28,1.26,1.25,1.24,1.23,1.22,1.21,1.19,1.18,1.17,1.16,1.155,1.15,1.145,1.14,1.135,1.13,1.125,1.12,1.115,1.11,1.1,1.09,1.08,1.07,1.06,1.04,1.02,1.01,1,0.99,0.98,0.97,0.96,0.95,0.94]
K = [0.050168888947062285,0.028326915947477632,0.018368461739116732,0.009914348295569022,0.00849442159047159,0.007181347467917699,0.006578044406341948,0.006010308394621633,0.005471799163822348,0.004975643278255809,0.0045173822060090175,0.0037267057077668897,0.003443443138233066,0.0031463598096312688,0.0029035585290936596,0.0028164560428649158,0.0027201612390321947,0.0026909843583357985,0.0026040242186276714,0.00255822445639083,0.0025413566400994533,0.002549973912240769,0.0025690384979873246,0.0025855184020031553,0.006590256040106604,0.006781894994524281,0.007022077999857779,0.007353686929109442,0.007756272583612415,0.00824831305967189,0.009544667086114204,0.0038233564300401914,0.003881258706488228,0.003826011249554647,0.0038491363229853524,0.0038608043432829657,0.0038921822265720676,0.003875315361526279,0.0038745809381776253,0.003884323182916795]

# %%
plt.plot(B, K)
plt.show()

# %%
B = [1.7,1.6,1.59,1.58,1.57,1.56,1.55,1.54,1.53,1.525,1.52,1.515,1.51,1.505,1.5,1.495]
K = [0.010902438618008584, 0.005688426848013074, 0.005244188686300311, 0.0048245960796689785, 0.004443422865291088, 0.004008227158159393, 0.0036103939728879143, 0.003282296583669059, 0.002928643583185034, 0.0027550076865724715, 0.00267921457246386, 0.0024662981897627004, 0.0022843616169491913, 0.0021276050768120175, 0.0020157166782807127, 0.0019267297356308538]

# %%
#R_v = 10. Primeira tabela
plt.plot(B, K)
plt.show()

# %%
# R_v = 7. Primeira tabela
B = [1.7, 1.6, 1.59, 1.58, 1.57, 1.56, 1.55, 1.54, 1.535, 1.53, 1.525, 1.52, 1.515, 1.51]
K = [0.010766614770993463, 0.005317740588331452, 0.004851328498387889, 0.004425301761909435, 0.0039867721853062395, 0.0035777081780930483, 0.003213226084994221, 0.0028300796853542747, 0.0026644225872169665, 0.002507264260625859, 0.002349990104042863, 0.002169014682038986, 0.002107165284493663, 0.001987329599808823]

# %%
plt.plot(B, K)
plt.show()

# %%
#R_v = 3. Primeira tabela
B = [1.7, 1.6, 1.5, 1.49, 1.48, 1.47, 1.46, 1.455, 1.45, 1.445, 1.44, 1.435, 1.425, 1.415, 1.405, 1.395, 1.39, 1.385, 1.38, 1.375, 1.37]
K = [0.017889180855096054, 0.010535645693306788,0.004629753073668074,  0.0041404610912490975, 0.0036739074979632498, 0.003234892470811958, 0.002826776972787365, 0.0026350222607136476, 0.002438110423052549, 0.0022503713771467354, 0.002073174718147615, 0.00421596280745732, 0.0038632139911126814, 0.0034609169886456043, 0.0030789304861121485, 0.002722285829884108, 0.0025431087885935534, 0.002395112951442414, 0.0022196204853514056, 0.0020655192482059263, 0.001924079256569539]

# %%
plt.plot(B, K)
plt.show()

# %%
#R_v =1. Primeira tabela
B = [1.7,1.6,1.5,1.4,1.38,1.36,1.35,1.34,1.33,1.32,1.31,1.30,1.29,1.28,1.27,1.265,1.26,1.255,1.25,1.245]
K = [0.037260740671623785,0.027385992713076786, 0.018099027893736856, 0.009997896859664327, 0.008576608355445875, 0.0072867834189643856, 0.00664963568450518, 0.006042509053693389, 0.005473847625159655, 0.00492680609509807, 0.004402472902746802, 0.003934136007027202, 0.0034827707752605346, 0.003065741469915365, 0.0027003830242069288, 0.0025244868844212422, 0.0023754005823645647, 0.0022058182878105627, 0.0020857094440043895, 0.0019525700441081334]
plt.plot(B, K)
plt.show()

# %%
(K[0] - K[19])
# Out:
# 0.03530817062751565

# %%
x=3.2530523

# %%
y=((np.exp(x*1.7))-np.exp((x*1.245)))/((np.exp(x*1.245))-(np.exp(x*1.31)))

# %%
y
# Out:
# -14.412069574748541

# %%
a=(K[0] - K[19])/(np.exp(x*1.7)-np.exp(1.245*x))

# %%
a
# Out:
# 0.0001812616175414535

# %%
c=K[0]-(a*np.exp(x*1.7))

# %%
#R_v =1. Primeira tabela
B = np.array([1.7,1.6,1.5,1.4,1.38,1.36,1.35,1.34,1.33,1.32,1.31,1.30,1.29,1.28,1.27,1.265,1.26,1.255,1.25,1.245])
K = np.array([0.037260740671623785,0.027385992713076786, 0.018099027893736856, 0.009997896859664327, 0.008576608355445875, 0.0072867834189643856, 0.00664963568450518, 0.006042509053693389, 0.005473847625159655, 0.00492680609509807, 0.004402472902746802, 0.003934136007027202, 0.0034827707752605346, 0.003065741469915365, 0.0027003830242069288, 0.0025244868844212422, 0.0023754005823645647, 0.0022058182878105627, 0.0020857094440043895, 0.0019525700441081334])
F = c+a*np.exp(x*B)
plt.plot(B,F,'r--')
plt.plot(B, K)
plt.show()

# %%
dF = []
for i in range(19):
    dF.append((K[i]-K[i+1])/(B[i]-B[i+1]))
dF.append(dF[18])

# %%
plt.plot(B, dF)
plt.show()

# %%
B = np.array([])
F = np.array([])
K = np.arange(0.001,0.1,0.0001)
for i in K:
    if i == 1e3:
            dRs = 5e-3
    else:
        if i >= 0.003:
             dRs = 0.03
        else:
            if i > 0.002:
                dRs = 0.02
            else:
                if i > 0.0017:
                    dRs = 0.01
                else:
                    if i >0.0013:
                        dRs = 0.005
                    else:
                        dRs = 0.002
    B = np.append(B,dRs)
    dRs2 = 255.7979*(i**3)-58.88093*(i**2)+1.674852*i-0.001116227
    
    F = np.append(F,dRs2)
plt.plot(K,F,'r--')

plt.show()
